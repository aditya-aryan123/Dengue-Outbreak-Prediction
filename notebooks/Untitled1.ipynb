# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.tseries.offsets import DateOffset

# %%
df = pd.read_csv('dengue_features_train.csv')
df1 = pd.read_csv('dengue_labels_train.csv')

# %%
merged_df = pd.merge(df, df1)

# %%
merged_df.to_csv('final.csv', index=False)

# %%
df.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# ...

# %%
df1 = pd.read_csv('dengue_labels_train.csv')

# %%
df_copy = df.copy()
df1_copy = df1.copy()

# %%
merged_df = pd.merge(df_copy, df1_copy)

# %%
pd.set_option('display.max_columns', 25)
merged_df.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# 0  0.177617                 12.42             297.572857
# 1  0.155486                 22.82             298.211429
# 2  0.170843                 34.54             298.781429
# 3  0.235886                 15.36             298.987143
# 4  0.247340                  7.52             299.518571
#
#    reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# 0             297.742857                   292.414286
# 1             298.442857                   293.951429
# ...

# %%
merged_df['total_cases'].hist(bins=100, figsize=(10, 7))
# Out:
# <AxesSubplot:>

# %%
merged_df.groupby('city')['total_cases'].sum().plot(kind='bar', figsize=(10, 7))
# Out:
# <AxesSubplot:xlabel='city'>

# %%
merged_df[merged_df['city']=='sj'].groupby('week_start_date')['total_cases'].mean().plot(figsize=(10, 7))
# Out:
# <AxesSubplot:xlabel='week_start_date'>

# %%
rough_frame = merged_df.copy()

# %%
rough_frame['week_start_date'] = pd.to_datetime(rough_frame['week_start_date'])
rough_frame = rough_frame.set_index('week_start_date')

# %%
rough_frame.index
# Out:
# DatetimeIndex(['1990-04-30', '1990-05-07', '1990-05-14', '1990-05-21',
#                '1990-05-28', '1990-06-04', '1990-06-11', '1990-06-18',
#                '1990-06-25', '1990-07-02',
#                ...
#                '2010-04-23', '2010-04-30', '2010-05-07', '2010-05-14',
#                '2010-05-21', '2010-05-28', '2010-06-04', '2010-06-11',
#                '2010-06-18', '2010-06-25'],
#               dtype='datetime64[ns]', name='week_start_date', length=1456, freq=None)

# %%
rough_frame.index -= DateOffset(weeks=4)

# %%
rough_frame.index
# Out:
# DatetimeIndex(['1990-04-02', '1990-04-09', '1990-04-16', '1990-04-23',
#                '1990-04-30', '1990-05-07', '1990-05-14', '1990-05-21',
#                '1990-05-28', '1990-06-04',
#                ...
#                '2010-03-26', '2010-04-02', '2010-04-09', '2010-04-16',
#                '2010-04-23', '2010-04-30', '2010-05-07', '2010-05-14',
#                '2010-05-21', '2010-05-28'],
#               dtype='datetime64[ns]', name='week_start_date', length=1456, freq=None)

# %%
df5 = merged_df.set_index('week_start_date')
df5.index = pd.to_datetime(df5.index)

# %%
plt.figure(figsize=(10, 7))
plt.plot(df5['total_cases'])
plt.plot(df5['precipitation_amt_mm'].resample('MS').mean())
plt.plot(rough_frame['precipitation_amt_mm'].resample('MS').mean())
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.plot(df5['total_cases'])
plt.plot(df5['reanalysis_air_temp_k'].resample('MS').sum())
plt.plot(rough_frame['reanalysis_air_temp_k'].resample('MS').sum())
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.plot(df5['total_cases'])
plt.plot(df5['reanalysis_dew_point_temp_k'].resample('MS').mean())
plt.plot(rough_frame['reanalysis_dew_point_temp_k'].resample('MS').mean())
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 7))
ax.plot(df5['precipitation_amt_mm'].resample('MS').mean())
ax.plot(rough_frame['precipitation_amt_mm'].resample('MS').mean())
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 7))
ax.plot(df5['reanalysis_air_temp_k'].resample('MS').mean())
ax.plot(rough_frame['reanalysis_air_temp_k'].resample('MS').mean())
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 7))
ax.plot(df5['reanalysis_dew_point_temp_k'].resample('MS').mean())
ax.plot(rough_frame['reanalysis_dew_point_temp_k'].resample('MS').mean())
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x=df4['precipitation_amt_mm'], y=df4['total_cases'])
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.lineplot(x=merged_df['year'], y=merged_df['total_cases'])
plt.show()

# %%
merged_df.groupby('year')['reanalysis_dew_point_temp_k'].mean().plot(figsize=(10, 7))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
merged_df.groupby('year')['reanalysis_relative_humidity_percent'].mean().plot(figsize=(10, 7))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
merged_df.groupby('year')['reanalysis_specific_humidity_g_per_kg'].mean().plot(figsize=(10, 7))
# Out:
# <AxesSubplot:xlabel='year'>

# %%
plt.plot(df4.groupby('year')['reanalysis_specific_humidity_g_per_kg'].sum())
plt.plot(df4.groupby('year')['total_cases'].sum())

# %%
df4 = merged_df.copy()
df4['temp_s7db'] = df4['reanalysis_air_temp_k'].shift(-7)
df4['temp_s30db'] = df4['reanalysis_air_temp_k'].shift(-30)

# %%
merged_df.loc[(merged_df['total_cases']>50), 'precipitation_amt_mm'].plot(kind='hist', bins=100, figsize=(20, 7))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import statsmodels.api as sm
from patsy import dmatrices

# %%
y, X = dmatrices('total_cases ~ precipitation_amt_mm', data=merged_df, return_type='dataframe')

# %%
mod = sm.OLS(y, X)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            total_cases   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.166
# Date:                Thu, 29 Sep 2022   Prob (F-statistic):              0.141
# Time:                        16:19:24   Log-Likelihood:                -7497.1
# No. Observations:                1443   AIC:                         1.500e+04
# Df Residuals:                    1441   BIC:                         1.501e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept               26.3866      1.666     15.843      0.000      23.120      29.654
# ...

# %%
res.params
# Out:
# Intercept               26.386645
# precipitation_amt_mm    -0.038738
# dtype: float64

# %%
res.rsquared
# Out:
# 0.0015007608587611632
